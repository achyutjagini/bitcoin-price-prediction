# %%
import pandas as pd 
from datetime import datetime
from datetime import timedelta
import os

from tqdm import tnrange, tqdm_notebook, tqdm

from sklearn import preprocessing

import numpy as np

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
def normalizeCol(col):
  col=list(col)
  maxx=max(col)
  mini=min(col)
  for i in range(len(col)):
    col[i]=(col[i]-mini)/(maxx-mini)
  return col

# %%
btc_data = pd.read_csv("/content/gdrive/My Drive/capstone project/modified datasets/Final_df.csv")
next_day_data=pd.read_csv("/content/gdrive/My Drive/capstone project/datasets/prices/Next_Day_Bitcoin_prices.csv")

# %%
next_day_data.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2021-02-06  38138.386719  40846.546875  38138.386719  39266.011719
# 1  2021-02-07  39250.191406  39621.835938  37446.152344  38903.441406
# 2  2021-02-08  38886.828125  46203.929688  38076.324219  46196.464844
# 3  2021-02-09  46184.992188  48003.722656  45166.960938  46481.105469
# 4  2021-02-10  46469.761719  47145.566406  43881.152344  44918.183594
#
#       Adj Close        Volume
# 0  39266.011719   71326033653
# 1  38903.441406   65500641143
# 2  46196.464844  101467222687
# 3  46481.105469   91809846886
# 4  44918.183594   87301089896

# %%
next_day_data.tail()
# Out:
#            Date          Open          High           Low         Close  \
# 431  2022-04-13  40123.570312  41430.054688  39712.746094  41166.730469
# 432  2022-04-14  41160.218750  41451.480469  39695.746094  39935.515625
# 433  2022-04-15  39939.402344  40617.722656  39866.832031  40553.464844
# 434  2022-04-16  40552.316406  40633.679688  40078.425781  40424.484375
# 435  2022-04-17  40417.777344  40570.726562  39620.894531  39716.953125
#
#         Adj Close       Volume
# 431  41166.730469  27691105228
# 432  39935.515625  24342001973
# 433  40553.464844  21756855753
# 434  40424.484375  16833150693
# 435  39716.953125  19087633042

# %% [markdown]
# df=btc_data

# %%
df=btc_data
df["next"]=next_day_data["Open"]

# %%
df
# Out:
#      Unnamed: 0        Date          Open          High           Low  \
# 0             0  2021-02-05  36931.546875  38225.906250  36658.761719
# 1             1  2021-02-06  38138.386719  40846.546875  38138.386719
# 2             2  2021-02-07  39250.191406  39621.835938  37446.152344
# 3             3  2021-02-08  38886.828125  46203.929688  38076.324219
# 4             4  2021-02-09  46184.992188  48003.722656  45166.960938
# ..          ...         ...           ...           ...           ...
# 431         431  2022-04-12  39533.714844  40617.585938  39388.328125
# 432         432  2022-04-13  40123.570312  41430.054688  39712.746094
# 433         433  2022-04-14  41160.218750  41451.480469  39695.746094
# 434         434  2022-04-15  39939.402344  40617.722656  39866.832031
# 435         435  2022-04-16  40552.316406  40633.679688  40078.425781
#
#             Close     Adj Close        Volume  Tweet_volume  Avg_score  \
# ...

# %%
df=df.drop(["Unnamed: 0","High","Low","Close","Adj Close","Volume","Tweet_volume","Avg_score"],axis=1)

# %%
df.Open=normalizeCol(df.Open)
df.next=normalizeCol(df.next)

# %%
#df=df.set_index('Date')

# %%
df
# Out:
#            Date      Open  Avg_score_norm  Tweet_volume_norm      next
# 0    2021-02-05  0.188996        0.043308           0.022462  0.220963
# 1    2021-02-06  0.220963        0.032583           0.044547  0.250412
# 2    2021-02-07  0.250412        0.000000           0.041089  0.240787
# 3    2021-02-08  0.240787        0.129953           0.077577  0.434098
# 4    2021-02-09  0.434098        0.136786           0.059494  0.441641
# ..          ...       ...             ...                ...       ...
# 431  2022-04-12  0.257922             NaN                NaN  0.273545
# 432  2022-04-13  0.273545        0.137809           0.255347  0.301004
# 433  2022-04-14  0.301004        0.153244           0.384722  0.268667
# 434  2022-04-15  0.268667        0.185499           0.564583  0.284902
# 435  2022-04-16  0.284902        0.116421           0.619726  0.281338
#
# [436 rows x 5 columns]

# %%
np.isnan(df["Avg_score_norm"]).count()
# Out:
# 436

# %%
df.to_csv('/content/gdrive/My Drive/capstone project/datasets/prices/Full_trial_data.csv',index=False)
