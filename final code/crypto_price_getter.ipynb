# %%
! pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.2 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
# Raw Package
import numpy as np
import pandas as pd

#Data Source
import yfinance as yf
import datetime
import time

# %%
def get_data(symbol, interval, start, end):
    data = yf.download(tickers=symbol, start=start, end=end, interval=interval)
    return data

# %%
def get_data(symbol, interval, start, end):
    data = yf.download(tickers=symbol, start=start, end=end, interval=interval)
    return data

symbol = "BTC-USD"
interval = "1d"
start = "2021-02-05"
end = "2022-04-18"
data = get_data(symbol, interval, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-02-06  38138.386719  40846.546875  38138.386719  39266.011719
# 2021-02-07  39250.191406  39621.835938  37446.152344  38903.441406
# 2021-02-08  38886.828125  46203.929688  38076.324219  46196.464844
# 2021-02-09  46184.992188  48003.722656  45166.960938  46481.105469
# 2021-02-10  46469.761719  47145.566406  43881.152344  44918.183594
# ...                  ...           ...           ...           ...
# 2022-04-13  40123.570312  41430.054688  39712.746094  41166.730469
# 2022-04-14  41160.218750  41451.480469  39695.746094  39935.515625
# 2022-04-15  39939.402344  40617.722656  39866.832031  40553.464844
# 2022-04-16  40552.316406  40633.679688  40078.425781  40424.484375
# 2022-04-17  40417.777344  40570.726562  39620.894531  39716.953125
#
#                Adj Close        Volume
# Date
# 2021-02-06  39266.011719   71326033653
# 2021-02-07  38903.441406   65500641143
# ...

# %%
data.drop("Adj Close",axis=1)
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-02-06  38138.386719  40846.546875  38138.386719  39266.011719
# 2021-02-07  39250.191406  39621.835938  37446.152344  38903.441406
# 2021-02-08  38886.828125  46203.929688  38076.324219  46196.464844
# 2021-02-09  46184.992188  48003.722656  45166.960938  46481.105469
# 2021-02-10  46469.761719  47145.566406  43881.152344  44918.183594
# ...                  ...           ...           ...           ...
# 2022-04-13  40123.570312  41430.054688  39712.746094  41166.730469
# 2022-04-14  41160.218750  41451.480469  39695.746094  39935.515625
# 2022-04-15  39939.402344  40617.722656  39866.832031  40553.464844
# 2022-04-16  40552.316406  40633.679688  40078.425781  40424.484375
# 2022-04-17  40417.777344  40570.726562  39620.894531  39716.953125
#
#                   Volume
# Date
# 2021-02-06   71326033653
# 2021-02-07   65500641143
# 2021-02-08  101467222687
# 2021-02-09   91809846886
# ...

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
#/content/gdrive/MyDrive/z0mgs_with_MW_LMC_220517_ww_w_gal_magnetar.npy

# %%
results=data.drop()
data.iloc[:-1 , :].to_csv('/content/gdrive/My Drive/capstone project/datasets/prices/Bitcoin_prices.csv',index=False)

# %%
data.iloc[1: , :]["Open"].to_csv('/content/gdrive/My Drive/capstone project/datasets/prices/Next_Day_Bitcoin_prices.csv',,index=False)

# %%
"""import pandas as pd
# List of Tuples
empoyees = [('Jack',    34, 'Sydney',   5) ,
            ('Riti',    31, 'Delhi' ,   7) ,
            ('Aadi',    16, 'London',   11) ,
            ('Mark',    41, 'Delhi' ,   12)]
# Create a DataFrame object
df = pd.DataFrame(  empoyees, 
                    columns=['Name', 'Age', 'City', 'Experience'])
print("Contents of the Dataframe : ")
print(df)
# Drop first row 
# by selecting all rows from first row onwards

print("Modified Dataframe : ",df.iloc[1:-1 , :])"""
